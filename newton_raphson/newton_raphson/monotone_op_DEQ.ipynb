# %%
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import numpy as np

# %% [markdown]
# ## First Get My Data

# %%
batch_size = 128
data_all = np.load('50k_holybro.npy')

# %%
class QuadrotorDataset(Dataset):
  def __init__(self, data_path = 'testing.csv', time_size=1, state_size = 9, ctrlinput_size = 4, training=True, data_all = data_all):
    self.input_size = state_size + ctrlinput_size
    self.output_size = ctrlinput_size

    self.data = data_all

    np.random.shuffle(data_all)
    train_size = int(len(data_all)*0.8)


    if training:
      self.data = data_all[0:train_size]
    else:
      self.data = data_all[train_size:]

    print(self.data.shape)

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    # print(self.data[idx,:])
    inputs = self.data[idx, 0: self.input_size]
    outputs = self.data[idx, self.input_size:]
    # print(type(inputs))
    # print(type(outputs))
    # print(inputs)
    # print(inputs.dtype)
    # print("h")
    return torch.FloatTensor(inputs), torch.FloatTensor(outputs)

# %%
train_dataset = QuadrotorDataset(training=True)
test_dataset = QuadrotorDataset(training=False)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
)
# Out:
# (40000, 17)
# (10000, 17)

# %% [markdown]
# ## Necessary Files for Building and Training INN

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.optim as optim
import numpy as np
import time
from torch.autograd import Function

# %% [markdown]
# ### MonSingleFC and MONReLU

# %%
class MONSingleFc(nn.Module):
    """ Simple MON linear class, just a single full multiply. """

    def __init__(self, in_dim, out_dim, m=1.0):
        super().__init__()
        self.U = nn.Linear(in_dim, out_dim)
        self.A = nn.Linear(out_dim, out_dim, bias=False)
        self.B = nn.Linear(out_dim, out_dim, bias=False)
        self.m = m

    def x_shape(self, n_batch):
        return (n_batch, self.U.in_features)

    def z_shape(self, n_batch):
        return ((n_batch, self.A.in_features),)

    def forward(self, x, *z):
        return (self.U(x) + self.multiply(*z)[0],)

    def bias(self, x):
        return (self.U(x),)

    def multiply(self, *z):
        ATAz = self.A(z[0]) @ self.A.weight
        z_out = (1 - self.m) * z[0] - ATAz + self.B(z[0]) - z[0] @ self.B.weight
        return (z_out,)

    def multiply_transpose(self, *g):
        ATAg = self.A(g[0]) @ self.A.weight
        g_out = (1 - self.m) * g[0] - ATAg - self.B(g[0]) + g[0] @ self.B.weight
        return (g_out,)

    def init_inverse(self, alpha, beta):
        I = torch.eye(self.A.weight.shape[0], dtype=self.A.weight.dtype,
                      device=self.A.weight.device)
        W = (1 - self.m) * I - self.A.weight.T @ self.A.weight + self.B.weight - self.B.weight.T
        self.Winv = torch.inverse(alpha * I + beta * W)

    def inverse(self, *z):
        return (z[0] @ self.Winv.transpose(0, 1),)

    def inverse_transpose(self, *g):
        return (g[0] @ self.Winv,)


class MONReLU(nn.Module):
    def forward(self, *z):
        return tuple(F.relu(z_) for z_ in z)

    def derivative(self, *z):
        return tuple((z_ > 0).type_as(z[0]) for z_ in z)

# %% [markdown]
# ### Splitting

# %% [markdown]
# #### 1.Utils

# %%
class Meter(object):
    """Computes and stores the min, max, avg, and current values"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        self.max = -float("inf")
        self.min = float("inf")

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        self.max = max(self.max, val)
        self.min = min(self.min, val)


class SplittingMethodStats(object):
    def __init__(self):
        self.fwd_iters = Meter()
        self.bkwd_iters = Meter()
        self.fwd_time = Meter()
        self.bkwd_time = Meter()

    def reset(self):
        self.fwd_iters.reset()
        self.fwd_time.reset()
        self.bkwd_iters.reset()
        self.bkwd_time.reset()

    def report(self):
        print('Fwd iters: {:.2f}\tFwd Time: {:.4f}\tBkwd Iters: {:.2f}\tBkwd Time: {:.4f}\n'.format(
                self.fwd_iters.avg, self.fwd_time.avg,
                self.bkwd_iters.avg, self.bkwd_time.avg))

# %% [markdown]
# #### 2.Splitting Files

# %%
class MONPeacemanRachford(nn.Module):

    def __init__(self, linear_module, nonlin_module, alpha=1.0, tol=1e-5, max_iter=50, verbose=False):
        super().__init__()
        self.linear_module = linear_module
        self.nonlin_module = nonlin_module
        self.alpha = alpha
        self.tol = tol
        self.max_iter = max_iter
        self.verbose = verbose
        self.stats = SplittingMethodStats()
        self.save_abs_err = False

    def forward(self, x):
        """ Forward pass of the MON, find an equilibirum with forward-backward splitting"""

        start = time.time()
        # Run the forward pass _without_ tracking gradients
        self.linear_module.init_inverse(1 + self.alpha, -self.alpha)
        with torch.no_grad():
            z = tuple(torch.zeros(s, dtype=x.dtype, device=x.device)
                      for s in self.linear_module.z_shape(x.shape[0]))
            u = tuple(torch.zeros(s, dtype=x.dtype, device=x.device)
                      for s in self.linear_module.z_shape(x.shape[0]))

            n = len(z)
            bias = self.linear_module.bias(x)

            err = 1.0
            it = 0
            errs = []
            while (err > self.tol and it < self.max_iter):
                u_12 = tuple(2 * z[i] - u[i] for i in range(n))
                z_12 = self.linear_module.inverse(*tuple(u_12[i] + self.alpha * bias[i] for i in range(n)))
                u = tuple(2 * z_12[i] - u_12[i] for i in range(n))
                zn = self.nonlin_module(*u)

                if self.save_abs_err:
                    fn = self.nonlin_module(*self.linear_module(x, *zn))
                    err = sum((zn[i] - fn[i]).norm().item() / (zn[i].norm().item()) for i in range(n))
                    errs.append(err)
                else:
                    err = sum((zn[i] - z[i]).norm().item() / (1e-6 + zn[i].norm().item()) for i in range(n))
                z = zn
                it = it + 1

        if self.verbose:
            print("Forward: ", it, err)

        # Run the forward pass one more time, tracking gradients, then backward placeholder
        zn = self.linear_module(x, *z)
        zn = self.nonlin_module(*zn)

        zn = self.Backward.apply(self, *zn)
        self.stats.fwd_iters.update(it)
        self.stats.fwd_time.update(time.time() - start)
        self.errs = errs
        return zn

    class Backward(Function):
        @staticmethod
        def forward(ctx, splitter, *z):
            ctx.splitter = splitter
            ctx.save_for_backward(*z)
            return z

        @staticmethod
        def backward(ctx, *g):
            start = time.time()
            sp = ctx.splitter
            n = len(g)
            z = ctx.saved_tensors
            j = sp.nonlin_module.derivative(*z)
            I = [j[i] == 0 for i in range(n)]
            d = [(1 - j[i]) / j[i] for i in range(n)]
            v = tuple(j[i] * g[i] for i in range(n))

            z = tuple(torch.zeros(s, dtype=g[0].dtype, device=g[0].device)
                      for s in sp.linear_module.z_shape(g[0].shape[0]))
            u = tuple(torch.zeros(s, dtype=g[0].dtype, device=g[0].device)
                      for s in sp.linear_module.z_shape(g[0].shape[0]))

            err = 1.0
            errs=[]
            it = 0
            while (err >sp.tol and it < sp.max_iter):
                u_12 = tuple(2 * z[i] - u[i] for i in range(n))
                z_12 = sp.linear_module.inverse_transpose(*u_12)
                u = tuple(2 * z_12[i] - u_12[i] for i in range(n))
                zn = tuple((u[i] + sp.alpha * (1 + d[i]) * v[i]) / (1 + sp.alpha * d[i]) for i in range(n))
                for i in range(n):
                    zn[i][I[i]] = v[i][I[i]]

                err = sum((zn[i] - z[i]).norm().item() / (1e-6 + zn[i].norm().item()) for i in range(n))
                errs.append(err)
                z = zn
                it = it + 1

            if sp.verbose:
                print("Backward: ", it, err)

            dg = sp.linear_module.multiply_transpose(*zn)
            dg = tuple(g[i] + dg[i] for i in range(n))

            sp.stats.bkwd_iters.update(it)
            sp.stats.bkwd_time.update(time.time() - start)
            sp.errs = errs
            return (None,) + dg

# %% [markdown]
# ### SingleFC Net and Support Functions

# %%
def expand_args(defaults, kwargs):
    d = defaults.copy()
    for k, v in kwargs.items():
        d[k] = v
    return d

MON_DEFAULTS = {
    'alpha': 1.0,
    'tol': 1e-5,
    'max_iter': 50
}

class SingleFcNet(nn.Module):

    def __init__(self, splittingMethod, in_dim=13, intermediate_dim=100, out_dim=4, m=0.1, **kwargs):
        super().__init__()
        linear_module = MONSingleFc(in_dim, intermediate_dim, m=m)
        nonlin_module = MONReLU()
        self.mon = splittingMethod(linear_module, nonlin_module, **expand_args(MON_DEFAULTS, kwargs))
        self.Wout = nn.Linear(intermediate_dim, out_dim)

    def forward(self, x):
        x = x.view(x.shape[0], -1)
        z = self.mon(x)
        return self.Wout(z[-1])

# %% [markdown]
# ### Training Function

# %%
def cuda(tensor):
    if torch.cuda.is_available():
        return tensor.cuda()
    else:
        return tensor
def run_tune_alpha(model, x, max_alpha):
    print("----tuning alpha----")
    print("current: ", model.mon.alpha)
    orig_alpha  =  model.mon.alpha
    model.mon.stats.reset()
    model.mon.alpha = max_alpha
    with torch.no_grad():
        model(x)
    iters = model.mon.stats.fwd_iters.val
    model.mon.stats.reset()
    iters_n = iters
    print('alpha: {}\t iters: {}'.format(model.mon.alpha, iters_n))
    while model.mon.alpha > 1e-4 and iters_n <= iters:
        model.mon.alpha = model.mon.alpha/2
        with torch.no_grad():
            model(x)
        iters = iters_n
        iters_n = model.mon.stats.fwd_iters.val
        print('alpha: {}\t iters: {}'.format(model.mon.alpha, iters_n))
        model.mon.stats.reset()

    if iters==model.mon.max_iter:
        print("none converged, resetting to current")
        model.mon.alpha=orig_alpha
    else:
        model.mon.alpha = model.mon.alpha * 2
        print("setting to: ", model.mon.alpha)
    print("--------------\n")

def train(trainLoader, testLoader, model, epochs=15, max_lr=1e-3,
          print_freq=10, change_mo=True, model_path=None, lr_mode='step',
          step=10,tune_alpha=False,max_alpha=1.):


    optimizer = optim.Adam(model.parameters(), lr=max_lr)

    if lr_mode == '1cycle':
        lr_schedule = lambda t: np.interp([t],
                                          [0, (epochs-5)//2, epochs-5, epochs],
                                          [1e-3, max_lr, 1e-3, 1e-3])[0]
    elif lr_mode == 'step':
        lr_scheduler =optim.lr_scheduler.StepLR(optimizer, step, gamma=0.1, last_epoch=-1)
    elif lr_mode != 'constant':
        raise Exception('lr mode one of constant, step, 1cycle')

    if change_mo:
        max_mo = 0.85
        momentum_schedule = lambda t: np.interp([t],
                                                [0, (epochs - 5) // 2, epochs - 5, epochs],
                                                [0.95, max_mo, 0.95, 0.95])[0]

    model = cuda(model)

    for epoch in range(1, 1 + epochs):
        nProcessed = 0
        nTrain = len(trainLoader.dataset)
        model.train()
        start = time.time()
        for batch_idx, batch in enumerate(trainLoader):
            if (batch_idx  == 30 or batch_idx == int(len(trainLoader)/2)) and tune_alpha:
                run_tune_alpha(model, cuda(batch[0]), max_alpha)
            if lr_mode == '1cycle':
                lr = lr_schedule(epoch -  1 + batch_idx/ len(trainLoader))
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
            if change_mo:
                beta1 = momentum_schedule(epoch - 1 + batch_idx / len(trainLoader))
                for param_group in optimizer.param_groups:
                    param_group['betas'] = (beta1, optimizer.param_groups[0]['betas'][1])

            data, target = cuda(batch[0]), cuda(batch[1])
            # print("HEREEEEEEE2")
            optimizer.zero_grad()
            preds = model(data)
            # print(data.shape)
            # print(preds.shape)
            # print(target.shape)
            ce_loss = nn.MSELoss()(preds, target)
            ce_loss.backward()
            nProcessed += len(data)
            if batch_idx % print_freq == 0 and batch_idx > 0:
            #     incorrect = preds.float().argmax(1).ne(target.data).sum()
            #     err = 100. * incorrect.float() / float(len(data))
                partialEpoch = epoch + batch_idx / len(trainLoader) - 1
                print('Train Epoch: {:.2f} [{}/{} ({:.0f}%)]\tLoss: {:.4f}'.format(
                    partialEpoch, nProcessed, nTrain,
                    100. * batch_idx / len(trainLoader),
                    ce_loss.item()))
                model.mon.stats.report()
                model.mon.stats.reset()
            optimizer.step()

        if lr_mode == 'step':
            lr_scheduler.step()

        if model_path is not None:
            torch.save(model.state_dict(), model_path)

        print("Tot train time: {}".format(time.time() - start))

        start = time.time()
        test_loss = 0
        incorrect = 0
        model.eval()
        with torch.no_grad():
            for batch in testLoader:
                data, target = cuda(batch[0]), cuda(batch[1])
                preds = model(data)
                ce_loss = nn.MSELoss(reduction='sum')(preds, target)
                test_loss += ce_loss
                # incorrect += preds.float().argmax(1).ne(target.data).sum()
            test_loss /= len(testLoader.dataset)
            # nTotal = len(testLoader.dataset)
            # err = 100. * incorrect.float() / float(nTotal)
            print('\n\nTest set: Test loss: {:.4f}'.format(
                test_loss))

        print("Tot test time: {}\n\n\n\n".format(time.time() - start))

# %% [markdown]
# ### Create Model

# %%
model_DEQ = SingleFcNet(MONPeacemanRachford,
                        in_dim = 13,
                        out_dim = 4,
                        alpha=1.0,
                        max_iter=300,
                        tol=1e-2,
                        m=1.0)

# %% [markdown]
# # Train It!

# %%
trainLoader, testLoader = train_dataloader, test_dataloader

train(trainLoader, testLoader,
      model_DEQ,
      max_lr=1e-3,
      lr_mode='step',
      step=10,
      change_mo=False,
      epochs=100,
    #   epochs=1,
      print_freq=100,
      tune_alpha=True)
# Out:
# ----tuning alpha----
# current:  1.0
# alpha: 1.0	 iters: 7
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 0.32 [12928/40000 (32%)]	Loss: 0.1433
# Fwd iters: 6.00	Fwd Time: 0.0025	Bkwd Iters: 6.00	Bkwd Time: 0.0037
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 8
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 0.64 [25728/40000 (64%)]	Loss: 0.0573
# Fwd iters: 6.00	Fwd Time: 0.0014	Bkwd Iters: 6.31	Bkwd Time: 0.0020
#
# Train Epoch: 0.96 [38528/40000 (96%)]	Loss: 0.0266
# Fwd iters: 6.00	Fwd Time: 0.0016	Bkwd Iters: 6.98	Bkwd Time: 0.0022
#
# Tot train time: 2.745835781097412
#
#
# Test set: Test loss: 0.0940
# Tot test time: 0.5010592937469482
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 8
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 1.32 [12928/40000 (32%)]	Loss: 0.0139
# Fwd iters: 6.00	Fwd Time: 0.0024	Bkwd Iters: 7.00	Bkwd Time: 0.0037
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 1.64 [25728/40000 (64%)]	Loss: 0.0111
# Fwd iters: 6.00	Fwd Time: 0.0026	Bkwd Iters: 7.00	Bkwd Time: 0.0040
#
# Train Epoch: 1.96 [38528/40000 (96%)]	Loss: 0.0079
# Fwd iters: 6.00	Fwd Time: 0.0026	Bkwd Iters: 7.00	Bkwd Time: 0.0043
#
# Tot train time: 3.907383918762207
#
#
# Test set: Test loss: 0.0335
# Tot test time: 0.49960994720458984
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 2.32 [12928/40000 (32%)]	Loss: 0.0073
# Fwd iters: 6.00	Fwd Time: 0.0026	Bkwd Iters: 7.01	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 2.64 [25728/40000 (64%)]	Loss: 0.0077
# Fwd iters: 6.00	Fwd Time: 0.0022	Bkwd Iters: 7.13	Bkwd Time: 0.0035
#
# Train Epoch: 2.96 [38528/40000 (96%)]	Loss: 0.0079
# Fwd iters: 6.00	Fwd Time: 0.0025	Bkwd Iters: 7.28	Bkwd Time: 0.0040
#
# Tot train time: 3.3692126274108887
#
#
# Test set: Test loss: 0.0254
# Tot test time: 0.4999558925628662
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 3.32 [12928/40000 (32%)]	Loss: 0.0042
# Fwd iters: 6.00	Fwd Time: 0.0026	Bkwd Iters: 7.45	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 3.64 [25728/40000 (64%)]	Loss: 0.0052
# Fwd iters: 6.00	Fwd Time: 0.0024	Bkwd Iters: 7.60	Bkwd Time: 0.0041
#
# Train Epoch: 3.96 [38528/40000 (96%)]	Loss: 0.0042
# Fwd iters: 6.00	Fwd Time: 0.0024	Bkwd Iters: 7.48	Bkwd Time: 0.0040
#
# Tot train time: 3.8564882278442383
#
#
# Test set: Test loss: 0.0158
# Tot test time: 0.4995090961456299
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 4.32 [12928/40000 (32%)]	Loss: 0.0026
# Fwd iters: 6.00	Fwd Time: 0.0028	Bkwd Iters: 7.41	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 4.64 [25728/40000 (64%)]	Loss: 0.0032
# Fwd iters: 6.02	Fwd Time: 0.0026	Bkwd Iters: 7.73	Bkwd Time: 0.0043
#
# Train Epoch: 4.96 [38528/40000 (96%)]	Loss: 0.0035
# Fwd iters: 6.09	Fwd Time: 0.0027	Bkwd Iters: 7.76	Bkwd Time: 0.0043
#
# Tot train time: 3.991957664489746
#
#
# Test set: Test loss: 0.0144
# Tot test time: 0.4963984489440918
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 6
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 5.32 [12928/40000 (32%)]	Loss: 0.0052
# Fwd iters: 6.24	Fwd Time: 0.0026	Bkwd Iters: 7.61	Bkwd Time: 0.0049
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 9
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 5.64 [25728/40000 (64%)]	Loss: 0.0030
# Fwd iters: 6.91	Fwd Time: 0.0027	Bkwd Iters: 7.60	Bkwd Time: 0.0042
#
# Train Epoch: 5.96 [38528/40000 (96%)]	Loss: 0.0028
# Fwd iters: 6.99	Fwd Time: 0.0029	Bkwd Iters: 7.85	Bkwd Time: 0.0044
#
# Tot train time: 4.116663217544556
#
#
# Test set: Test loss: 0.0128
# Tot test time: 0.5158355236053467
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 6.32 [12928/40000 (32%)]	Loss: 0.0025
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 7.80	Bkwd Time: 0.0043
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 6.64 [25728/40000 (64%)]	Loss: 0.0034
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 7.58	Bkwd Time: 0.0041
#
# Train Epoch: 6.96 [38528/40000 (96%)]	Loss: 0.0031
# Fwd iters: 7.00	Fwd Time: 0.0030	Bkwd Iters: 7.95	Bkwd Time: 0.0049
#
# Tot train time: 4.134918212890625
#
#
# Test set: Test loss: 0.0136
# Tot test time: 0.5121052265167236
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 7.32 [12928/40000 (32%)]	Loss: 0.0018
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 7.94	Bkwd Time: 0.0045
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 7.64 [25728/40000 (64%)]	Loss: 0.0023
# Fwd iters: 7.00	Fwd Time: 0.0030	Bkwd Iters: 7.82	Bkwd Time: 0.0044
#
# Train Epoch: 7.96 [38528/40000 (96%)]	Loss: 0.0023
# Fwd iters: 7.00	Fwd Time: 0.0029	Bkwd Iters: 7.99	Bkwd Time: 0.0045
#
# Tot train time: 4.258544445037842
#
#
# Test set: Test loss: 0.0072
# Tot test time: 0.5285944938659668
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 8.32 [12928/40000 (32%)]	Loss: 0.0027
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 7.90	Bkwd Time: 0.0044
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 8.64 [25728/40000 (64%)]	Loss: 0.0015
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0046
#
# Train Epoch: 8.96 [38528/40000 (96%)]	Loss: 0.0023
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 7.94	Bkwd Time: 0.0044
#
# Tot train time: 4.126611948013306
#
#
# Test set: Test loss: 0.0069
# Tot test time: 0.5511515140533447
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 9.32 [12928/40000 (32%)]	Loss: 0.0014
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 9.64 [25728/40000 (64%)]	Loss: 0.0017
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0045
#
# Train Epoch: 9.96 [38528/40000 (96%)]	Loss: 0.0015
# Fwd iters: 7.00	Fwd Time: 0.0029	Bkwd Iters: 8.00	Bkwd Time: 0.0045
#
# Tot train time: 4.14644980430603
#
#
# Test set: Test loss: 0.0057
# Tot test time: 0.52565598487854
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 10.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 10.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0045
#
# Train Epoch: 10.96 [38528/40000 (96%)]	Loss: 0.0013
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# Tot train time: 4.11327052116394
#
#
# Test set: Test loss: 0.0046
# Tot test time: 0.4922764301300049
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 11.32 [12928/40000 (32%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 11.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 11.96 [38528/40000 (96%)]	Loss: 0.0012
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# Tot train time: 4.043716669082642
#
#
# Test set: Test loss: 0.0047
# Tot test time: 0.5293595790863037
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 12.32 [12928/40000 (32%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0045
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 12.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Train Epoch: 12.96 [38528/40000 (96%)]	Loss: 0.0015
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Tot train time: 4.028995037078857
#
#
# Test set: Test loss: 0.0045
# Tot test time: 0.5133256912231445
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 13.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 13.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 13.96 [38528/40000 (96%)]	Loss: 0.0012
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# Tot train time: 3.9909982681274414
#
#
# Test set: Test loss: 0.0043
# Tot test time: 0.5015065670013428
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 14.32 [12928/40000 (32%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 14.64 [25728/40000 (64%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# Train Epoch: 14.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Tot train time: 3.983830451965332
#
#
# Test set: Test loss: 0.0043
# Tot test time: 0.5032365322113037
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 15.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0029	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 15.64 [25728/40000 (64%)]	Loss: 0.0013
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0045
#
# Train Epoch: 15.96 [38528/40000 (96%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.998414993286133
#
#
# Test set: Test loss: 0.0042
# Tot test time: 0.5024516582489014
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 16.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 16.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Train Epoch: 16.96 [38528/40000 (96%)]	Loss: 0.0014
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Tot train time: 3.9981637001037598
#
#
# Test set: Test loss: 0.0041
# Tot test time: 0.49599146842956543
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 17.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 17.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Train Epoch: 17.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Tot train time: 3.9657318592071533
#
#
# Test set: Test loss: 0.0041
# Tot test time: 0.49520421028137207
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 18.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 18.64 [25728/40000 (64%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# Train Epoch: 18.96 [38528/40000 (96%)]	Loss: 0.0015
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Tot train time: 3.988002300262451
#
#
# Test set: Test loss: 0.0038
# Tot test time: 0.5001533031463623
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 19.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 19.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 19.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0029	Bkwd Iters: 8.00	Bkwd Time: 0.0044
#
# Tot train time: 3.998891592025757
#
#
# Test set: Test loss: 0.0036
# Tot test time: 0.5004074573516846
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 20.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 20.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Train Epoch: 20.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.8979272842407227
#
#
# Test set: Test loss: 0.0036
# Tot test time: 0.47466278076171875
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 21.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 21.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 21.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.8905818462371826
#
#
# Test set: Test loss: 0.0035
# Tot test time: 0.5035083293914795
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 22.32 [12928/40000 (32%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 22.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 22.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7838146686553955
#
#
# Test set: Test loss: 0.0035
# Tot test time: 0.47571492195129395
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 23.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 23.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 23.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.8052773475646973
#
#
# Test set: Test loss: 0.0035
# Tot test time: 0.43746232986450195
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 24.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 24.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 24.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0027	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.806993007659912
#
#
# Test set: Test loss: 0.0035
# Tot test time: 0.47937917709350586
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 25.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 25.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 25.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0029	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.862147808074951
#
#
# Test set: Test loss: 0.0035
# Tot test time: 0.510674238204956
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 26.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 26.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 26.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.830505132675171
#
#
# Test set: Test loss: 0.0035
# Tot test time: 0.47971200942993164
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 27.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 27.64 [25728/40000 (64%)]	Loss: 0.0006
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 27.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.879110336303711
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4975714683532715
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 28.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 9
# setting to:  0.5
# --------------
#
# Train Epoch: 28.64 [25728/40000 (64%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 28.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.763706684112549
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.49190306663513184
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 29.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 29.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 29.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.8042314052581787
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.49696779251098633
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 30.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 30.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 30.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.814666271209717
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4797346591949463
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 9
# setting to:  0.5
# --------------
#
# Train Epoch: 31.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 31.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 31.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.831352949142456
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.49875879287719727
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 32.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 32.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 32.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Tot train time: 3.860985279083252
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.486330509185791
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 33.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 33.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 33.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.8194475173950195
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.48023509979248047
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 34.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 34.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 34.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.7392239570617676
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4971952438354492
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 35.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 35.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0028	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 35.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.779764413833618
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47498202323913574
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 36.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 36.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 36.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.7828683853149414
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47822999954223633
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 37.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 37.64 [25728/40000 (64%)]	Loss: 0.0012
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.02	Bkwd Time: 0.0041
#
# Train Epoch: 37.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.8131344318389893
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4967927932739258
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 38.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 38.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 38.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.729933023452759
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.48061299324035645
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 39.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 39.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 39.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.701082944869995
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4739861488342285
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 40.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 40.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 40.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7263128757476807
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.48961448669433594
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 41.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 41.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 41.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.764045000076294
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4812965393066406
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 42.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 9
# setting to:  0.5
# --------------
#
# Train Epoch: 42.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0030	Bkwd Iters: 8.00	Bkwd Time: 0.0045
#
# Train Epoch: 42.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.7783515453338623
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47214627265930176
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 43.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 43.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 43.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7119481563568115
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4765305519104004
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 44.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 44.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 44.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.792421817779541
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.49355053901672363
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 45.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 45.64 [25728/40000 (64%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 45.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7948997020721436
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4805872440338135
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 46.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 46.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 46.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.780843496322632
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4732816219329834
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 47.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 9
# setting to:  0.5
# --------------
#
# Train Epoch: 47.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 47.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7869298458099365
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.48138427734375
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 48.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 48.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 48.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.7262818813323975
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47178173065185547
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 49.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 49.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 49.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.73287034034729
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4879426956176758
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 50.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 50.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 50.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.754775285720825
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4623560905456543
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 51.32 [12928/40000 (32%)]	Loss: 0.0011
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 11
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 51.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0043
#
# Train Epoch: 51.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.747239589691162
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4815640449523926
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 52.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 52.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 52.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.688660144805908
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.45893120765686035
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 9
# setting to:  0.5
# --------------
#
# Train Epoch: 53.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 53.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 53.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.769829034805298
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4671504497528076
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 54.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 54.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 54.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0023	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.659416437149048
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4704141616821289
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 55.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0038
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 55.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 55.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.671506881713867
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4745044708251953
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 56.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 56.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 56.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6653754711151123
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47390270233154297
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 57.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0038
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 57.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 57.96 [38528/40000 (96%)]	Loss: 0.0012
# Fwd iters: 7.00	Fwd Time: 0.0023	Bkwd Iters: 8.00	Bkwd Time: 0.0038
#
# Tot train time: 3.600883722305298
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.456134557723999
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 58.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 58.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 58.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6952602863311768
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4636263847351074
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 59.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 59.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 59.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.673564910888672
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47882699966430664
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 60.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 60.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 60.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.722146987915039
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47939515113830566
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 61.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 61.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 61.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.7044787406921387
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4611482620239258
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 62.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 62.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 62.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.649097204208374
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4745936393737793
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 63.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 63.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 63.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6808574199676514
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4777348041534424
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 64.32 [12928/40000 (32%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 64.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 64.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7617223262786865
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.46662378311157227
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 65.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 65.64 [25728/40000 (64%)]	Loss: 0.0009
# ...
# setting to:  0.5
# --------------
#
# Train Epoch: 78.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 78.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 78.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.735719680786133
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4687995910644531
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 79.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 79.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 79.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.774982213973999
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4911689758300781
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 80.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 80.64 [25728/40000 (64%)]	Loss: 0.0006
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 80.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0023	Bkwd Iters: 8.00	Bkwd Time: 0.0038
#
# Tot train time: 3.6394288539886475
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4630272388458252
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 81.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 81.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 81.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7133100032806396
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.48069238662719727
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 82.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 82.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 82.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.662351608276367
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4751269817352295
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 83.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 83.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 83.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.7743446826934814
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47411513328552246
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 84.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 84.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Train Epoch: 84.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.667604446411133
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.470548152923584
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 85.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 85.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 85.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6968305110931396
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4678328037261963
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 86.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 86.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 86.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.7249763011932373
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4770181179046631
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 87.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 87.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 87.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7255842685699463
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4851343631744385
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 88.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 88.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 88.96 [38528/40000 (96%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6984753608703613
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4583241939544678
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 89.32 [12928/40000 (32%)]	Loss: 0.0006
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 89.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 89.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6539063453674316
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.46901941299438477
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 90.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 90.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0042
#
# Train Epoch: 90.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7698965072631836
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.483290433883667
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 9
# setting to:  0.5
# --------------
#
# Train Epoch: 91.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 91.64 [25728/40000 (64%)]	Loss: 0.0006
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 91.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6726784706115723
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4706456661224365
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 92.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 92.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 92.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# Tot train time: 3.7149858474731445
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4942970275878906
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 93.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 93.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 93.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.668539524078369
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.47896885871887207
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 94.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 94.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 94.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Tot train time: 3.6906754970550537
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.45925331115722656
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 95.32 [12928/40000 (32%)]	Loss: 0.0006
# Fwd iters: 7.00	Fwd Time: 0.0026	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 95.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 95.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.7003040313720703
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.4697890281677246
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 96.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 96.64 [25728/40000 (64%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 96.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.692775011062622
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.46968507766723633
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 97.32 [12928/40000 (32%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 97.64 [25728/40000 (64%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0023	Bkwd Iters: 8.00	Bkwd Time: 0.0038
#
# Train Epoch: 97.96 [38528/40000 (96%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6625335216522217
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.478287935256958
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 98.32 [12928/40000 (32%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 98.64 [25728/40000 (64%)]	Loss: 0.0010
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Train Epoch: 98.96 [38528/40000 (96%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.6864078044891357
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.46825718879699707
#
#
#
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 99.32 [12928/40000 (32%)]	Loss: 0.0007
# Fwd iters: 7.00	Fwd Time: 0.0025	Bkwd Iters: 8.00	Bkwd Time: 0.0041
#
# ----tuning alpha----
# current:  0.5
# alpha: 1.0	 iters: 10
# alpha: 0.5	 iters: 7
# alpha: 0.25	 iters: 8
# setting to:  0.5
# --------------
#
# Train Epoch: 99.64 [25728/40000 (64%)]	Loss: 0.0009
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0039
#
# Train Epoch: 99.96 [38528/40000 (96%)]	Loss: 0.0008
# Fwd iters: 7.00	Fwd Time: 0.0024	Bkwd Iters: 8.00	Bkwd Time: 0.0040
#
# Tot train time: 3.707376480102539
#
#
# Test set: Test loss: 0.0034
# Tot test time: 0.46190881729125977

# %% [markdown]
# # Test It!

# %%
i = 0
bad = 0
num_trials = 1000
for data in train_dataloader:
    input_data, output_data = data
    # print(input_data[0])
    # print(output_data[0])
    output_pred = model_DEQ(input_data)
    # print(output_pred[0])
    if ((output_pred[0] - output_data[0]) < torch.tensor([.08]*4)).all():
        pass
        # print("Good Prediction!")
    else:
        bad +=1
        # print("Bad Prediction")

    i += 1
    if i >= 100:
        print(f"error pct: {(bad/num_trials)*100}%")
        break
# Out:
# error pct: 0.1%

# %% [markdown]
# # Save the Model!

# %%
SAVE_PATH = "holybro_deq.pt"
torch.save(model_DEQ.state_dict(), SAVE_PATH)

# %% [markdown]
# # Test A Pretrained INN

# %%
loaded_model = SingleFcNet(MONPeacemanRachford,
                        in_dim = 13,
                        out_dim = 4,
                        alpha=1.0,
                        max_iter=300,
                        tol=1e-2,
                        m=1.0)

# %%
LOAD_PATH = "holybro_deq.pt"
loaded_model.load_state_dict(torch.load(LOAD_PATH))
# Out:
# <All keys matched successfully>

# %%
i = 0
bad = 0
num_trials = 1000
for data in train_dataloader:
    input_data, output_data = data
    # print(input_data[0])
    # print(output_data[0])
    output_pred = loaded_model(input_data)
    # print(output_pred[0])
    if ((output_pred[0] - output_data[0]) < torch.tensor([.08]*4)).all():
        pass
        # print("Good Prediction!")
    else:
        bad +=1
        # print("Bad Prediction")

    i += 1
    if i >= 100:
        print(f"error pct: {(bad/num_trials)*100}%")
        break
# Out:
# error pct: 0.4%
